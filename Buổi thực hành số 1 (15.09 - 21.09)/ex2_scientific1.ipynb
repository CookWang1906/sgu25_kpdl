# %% [markdown]
# # <center>**ex2_scientific1**<center>

# %% [markdown]
# ## **Nội dung bài**
#
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# ---
# ## <center>**Bài làm**<center>

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# generate randomly the center (x, y) of circle, color and area.
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: user 0 ns, sys: 6 µs, total: 6 µs
# Wall time: 11.9 µs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.06, 0.96]: 10 samples [[0.75110669 0.76948029 0.31190706 0.42941397 0.26362662 0.45025769
#  0.22680532 0.34977413 0.17543202 0.92621442]]
# + y: len=50, [0.02, 0.99]: 10 samples [[0.57221496 0.95773633 0.57196176 0.22127817 0.50957758 0.57581398
#  0.91554344 0.05607364 0.09418634 0.85005623]]
# + colors: len=50, [0.01, 0.97]: 10 samples [[0.59408438 0.58448148 0.96873244 0.58148894 0.9571216  0.56195919
#  0.43169764 0.82486633 0.10380245 0.20632631]]
# + area: len=50, [0.09, 590.68]: 10 samples [[3.81017678e-01 2.36077172e+02 4.58669580e+02 3.99682085e+01
#  1.46570730e+01 5.78425510e+01 2.95376619e+02 3.97846333e+02
#  9.36427679e+00 4.90214841e+02]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # <center>**KẾT THÚC**<center>
